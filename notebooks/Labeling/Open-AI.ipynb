# %%
# %pip install openai backoff
# Out:
# Collecting openai
#   Downloading openai-0.27.7-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests>=2.20 in /home/andreas/Polybox/Project-Support-Material/Thesis/.venv/lib/python3.10/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /home/andreas/Polybox/Project-Support-Material/Thesis/.venv/lib/python3.10/site-packages (from openai) (4.65.0)
# Collecting aiohttp (from openai)
#   Using cached aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/andreas/Polybox/Project-Support-Material/Thesis/.venv/lib/python3.10/site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/andreas/Polybox/Project-Support-Material/Thesis/.venv/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/andreas/Polybox/Project-Support-Material/Thesis/.venv/lib/python3.10/site-packages (from requests>=2.20->openai) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andreas/Polybox/Project-Support-Material/Thesis/.venv/lib/python3.10/site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in /home/andreas/Polybox/Project-Support-Material/Thesis/.venv/lib/python3.10/site-packages (from aiohttp->openai) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai)
#   Using cached multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->openai)
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai)
#   Using cached yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->openai)
#   Using cached frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->openai)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.7 yarl-1.9.2

# %%
from pathlib import Path
import backoff 
import openai
import pickle
import time
import pandas as pd

from dotenv import dotenv_values

config = dotenv_values("./../../config/.env") # take environment variables from .env.
openai.organization = config["OPEN_AI_ORG"]
openai.api_key = config["OPEN_AI_TOKEN"]

annotations = pd.read_pickle(Path(config["BASE_PATH"])/"data/labeling/active-learning-labeling-gpt.pkl")
annotations = annotations[annotations.labeled]
if "gpt_loss" not in annotations.columns:
    annotations["gpt_loss"] = None
    annotations["gpt_unexpected"] = None

model = "gpt-3.5-turbo"

@backoff.on_exception(backoff.expo, openai.error.RateLimitError, on_backoff=lambda x: print(f"""Backing off: {round(x['wait'])} seconds"""), )
def completions_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)

# %%
query_template = """Does the following sequence contain (True) or not (False) a statement which describes or refers to {label}?
Sequence: {sequence}
Label: """

labels = {
    "loss": "a financial/business loss, or adverse business development experienced by the reporting entity",
    "unexpected": "an unexpected event or development experienced by, or related to the reporting entity"
}

# %%
responses = []
for i, x in annotations[annotations.gpt_loss.apply(lambda x: x is None)][:40].iterrows():
    for l in labels:
        response = completions_with_backoff(
            model=model,
            messages=[
                {"role": "system", "content": "You are a research assistant paid for labeling the following statements as accurately as possible. Please return the label as True or False."},
                {"role": "user", "content": query_template.format(sequence=x.text, label=labels[l])},
            ],
            temperature=0.2,
            max_tokens=10)
        annotations.loc[i, f"gpt_{l}"] = response.choices[0].message.content
        responses.append(
            {
                "index": i,
                "label": l,
                "response": response
            }
        )
        with open(Path(config["BASE_PATH"])/"data/labeling/gpt-responses.pkl", "wb") as f:
            pickle.dump(responses, f)
        annotations.to_pickle(Path(config["BASE_PATH"])/"data/labeling/active-learning-labeling-gpt.pkl")
        time.sleep(20)
    print(i)
# Out:
# 37910
# 38345
# 38409
# 38464
# 38570
# 38653
# 39081
# 39181
# 39371
# 39949
# 40169
# 40368
# 40544
# 40595
# 40754
# 40799
# 40826
# 40959
# 40975
# 41417
# 41477
# 41533
# 41568
# 41675
# 41936
# 42032
# 42145
# 42260
# 42410
# 42430
# 42436
# 42551
# 42591
# 42600
# 42613
# 42646
# 42880
# 43702
# 43716
# 43787

# %%
annotations[annotations.gpt_loss.apply(lambda x: x is not None)][[]]#.shape
# Out:
#                      report_id  paragraph_nr  \
# 1874                      1946           844
# 1962                      5879          1436
# 2100                      2987          2109
# 2534   AdmiralGroupPLC-AR_2013           184
# 2577                      1080           627
# ...                        ...           ...
# 42646                     2844           870
# 42880    StorebrandASA-AR_2000           115
# 43702                     5023          1616
# 43716                     5183           787
# 43787                     4999          2065
#
#                                                     text  n_words  \
# 1874   million. These actions were taken as a result ...      203
# 1962   (2) Underwriting income (loss), adjusted under...       71
# 2100   Reserves are reestimated quarterly, by combini...      263
# 2534   2013 was yet another good year for Admiral, bu...       28
# 2577   In December 1997, the Company began a comprehe...      278
# ...                                                  ...      ...
# 42646  The increase in net loss for Interest Expense ...       56
# 42880  A greenhouse for growth New technology and cha...      126
# 43702  The methodology and revised assumptions the Co...       80
# 43716  Overall industry-wide loss experience data and...      174
# 43787  Net premiums earned decreased by $31.6 million...       56
#
#          filing_type                   logits_loss  \
# 1874             10K    [-0.11371928, -0.12775159]
# 1962             10K    [-0.09082798, -0.09680451]
# 2100             10K       [-1.2206439, 1.1299531]
# 2534   annual_report       [-3.4491937, 3.7907827]
# 2577             10K        [1.8032632, -2.389743]
# ...              ...                           ...
# 42646            10K      [0.85338163, -1.1634406]
# 42880  annual_report       [-1.9969531, 2.1821964]
# 43702            10K  [-0.023726357, -0.039020926]
# 43716            10K  [-0.042522077, -0.052653357]
# 43787            10K  [-0.051938508, -0.036665082]
#
#                                  logits_unexpected loss unexpected labeled  \
# 1874     [-1.8307474851608276, 1.9387129545211792]    0          0    True
# 1962     [-2.8704769611358643, 3.2351996898651123]    0          0    True
# 2100    [0.1147109791636467, -0.06223767250776291]    0          0    True
# 2534    [0.11399621516466141, 0.15437042713165283]    0          0    True
# 2577     [-1.3694382905960083, 1.5590710639953613]    1          0    True
# ...                                            ...  ...        ...     ...
# 42646  [0.16455049812793732, -0.05269180238246918]    0          0    True
# 42880    [0.08060984313488007, 0.2991379201412201]    0          0    True
# 43702     [-2.0807933807373047, 2.091275453567505]    0          0    True
# 43716    [-1.6770411729812622, 1.8301029205322266]    1          0    True
# 43787     [-2.5092673301696777, 2.552517890930176]    0          0    True
#
#             strategy    p_loss  p_unexpected gpt_loss gpt_unexpected
# 1874         lc_loss  0.503508      0.022545    False          False
# 1962         lc_loss  0.501494      0.002225    False          False
# 2100   lc_unexpected  0.087018      0.544122    False          False
# 2534   lc_unexpected  0.000717      0.489908    False          False
# 2577       hc_t_loss  0.985124      0.050762     True           True
# ...              ...       ...           ...      ...            ...
# 42646  lc_unexpected  0.882552      0.554098     True          False
# 42880  lc_unexpected  0.015081      0.445584    False          False
# 43702        lc_loss  0.503824      0.015186     True          False
# 43716        lc_loss  0.502533      0.029110     True           True
# 43787        lc_loss  0.496182      0.006294     True          False
#
# [200 rows x 15 columns]

# %%
from sklearn.metrics import classification_report

# %%
df = annotations[annotations.gpt_loss.apply(lambda x: x is not None)]
df.gpt_loss = df.gpt_loss.apply(lambda x: int(x == "True"))
df.gpt_unexpected = df.gpt_unexpected.apply(lambda x: int(x == "True"))
# Out:
# /tmp/ipykernel_365520/3081219084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.gpt_loss = df.gpt_loss.apply(lambda x: int(x == "True"))
# /tmp/ipykernel_365520/3081219084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.gpt_unexpected = df.gpt_unexpected.apply(lambda x: int(x == "True"))

# %%
print(classification_report(df.loss.to_list(), df.gpt_loss.to_list()))
print(classification_report(df.loss.to_list(), (df.p_loss > 0.5).astype(int).to_list()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.66      0.79       137
#            1       0.57      0.95      0.71        63
#
#     accuracy                           0.76       200
#    macro avg       0.77      0.81      0.75       200
# weighted avg       0.84      0.76      0.76       200
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82       137
#            1       0.60      0.87      0.71        63
#
#     accuracy                           0.78       200
#    macro avg       0.77      0.81      0.77       200
# weighted avg       0.83      0.78      0.79       200

# %%
print(classification_report(df.unexpected.to_list(), df.gpt_unexpected.to_list()))
print(classification_report(df.unexpected.to_list(), (df.p_unexpected > 0.5).astype(int).to_list()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.48      0.64       183
#            1       0.11      0.71      0.19        17
#
#     accuracy                           0.50       200
#    macro avg       0.53      0.59      0.42       200
# weighted avg       0.88      0.50      0.60       200
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.56      0.71       183
#            1       0.16      0.94      0.28        17
#
#     accuracy                           0.59       200
#    macro avg       0.58      0.75      0.50       200
# weighted avg       0.92      0.59      0.68       200
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56        93
#            1       0.61      0.55      0.58       107
#
#     accuracy                           0.57       200
#    macro avg       0.57      0.57      0.57       200
# weighted avg       0.57      0.57      0.57       200

# %%
df[(df.gpt_loss != df.loss)][["text","gpt_loss", "loss"]]
# Out:
#                                                     text  gpt_loss loss
# 3082   We expect to continue to experience unpredicta...         1    0
# 3196   The primary sources of funds for Unitrin’s ins...         1    0
# 3726   The most important line of business in propert...         1    0
# 3745   We entered into a deferred compensation agreem...         1    0
# 3954   and cash equivalents in 2017 was due to paymen...         1    0
# 4018   While the Company has obtained insurance, impl...         1    0
# 4372   In the beginning of the year the tax treatment...         1    0
# 4977   P eople are living ever longer and can afford ...         1    0
# 5469   Mandatum Life to change its focus from new sal...         1    0
# 5632   portfolio for declines in value that are other...         1    0
# 5784   The operating losses incurred by the Company o...         1    0
# 6564   to €138 million, due to the non recurrence of ...         1    0
# 7008   We had built a rating for this and were tradin...         1    0
# 7157   · Events or actions, including unauthorized in...         1    0
# 8092   A number of lawsuits have been filed against f...         1    0
# 8880   Changing climate conditions could also impact ...         1    0
# 9059   In Australia, life and pension sales decreased...         1    0
# 10241  Persistency. Persistency is a measure of how l...         1    0
# 11042  Although we model various catastrophic perils,...         1    0
# 12196  The availability and cost of reinsurance are s...         1    0
# 13219  A hard market has sometimes been precipitated ...         1    0
# 13259  On June 2, 1998, the Company entered into a se...         1    0
# 16423  The uncertainties arise out of changes or pote...         1    0
# 17489  Losses and related loss adjustment expenses ar...         1    0
# 19696  Losses in our group life and accident and heal...         1    0
# 20826  began in the latter part of the first quarter ...         1    0
# 21584  EUR 3.3 million from the FSA due to systems an...         1    0
# 22103  in 2009, we have experienced an unprecedented ...         1    0
# 22913  The rally in financial markets during 2009 and...         1    0
# 23872  Many of our clients put their contracts out fo...         1    0
# 26046  The Company has fully cooperated with the atto...         1    0
# 26957  Our business is highly dependent upon the succ...         1    0
# 28183  Reinsurance contracts do not relieve the Compa...         1    0
# 30537  The loss ratios for the StarStone segment were...         0    1
# 36328  Many of our reinsurance treaties, notably in t...         1    0
# 37910  PEOPLE We are lucky to have excellent non-exec...         1    0
# 39181  As a result, there can be no assurance that we...         1    0
# 40595  Amounts are reported gross of reinsurance. As ...         1    0
# 40754  Inadequate Pricing Risk is the risk that the p...         1    0
# 40799  Estimates of the ultimate liabilities for trad...         0    1
# 40975  Provided that major-loss experience from now o...         1    0
# 41477  When taking out home insurance most customers ...         1    0
# 42430  · Our controls and procedures may fail or be c...         1    0
# 42436  Against this backdrop, it is to be considered ...         0    1
# 42551  2.Mortality experience continues to be better ...         1    0
# 42591  Unsurprisingly, 2009 was also shaped by the sh...         1    0
# 42646  The increase in net loss for Interest Expense ...         1    0
# 43702  The methodology and revised assumptions the Co...         1    0
# 43787  Net premiums earned decreased by $31.6 million...         1    0

# %%
df[(df.gpt_unexpected != df.unexpected)][["text","gpt_loss", "loss"]]
# Out:
#                                                     text  gpt_loss loss
# 2577   In December 1997, the Company began a comprehe...         1    1
# 2770   In 2000, the provision for incurred losses and...         1    1
# 3082   We expect to continue to experience unpredicta...         1    0
# 3196   The primary sources of funds for Unitrin’s ins...         1    0
# 3726   The most important line of business in propert...         1    0
# ...                                                  ...       ...  ...
# 41936  A CHF 633 million operating loss for 2002 refl...         1    1
# 42145  In Q4 2015, the Polish 10-year treasury bonds ...         0    0
# 42430  · Our controls and procedures may fail or be c...         1    0
# 42436  Against this backdrop, it is to be considered ...         0    1
# 43716  Overall industry-wide loss experience data and...         1    1
#
# [100 rows x 3 columns]
